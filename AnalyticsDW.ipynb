-- %% [markdown]
-- # [AnalyticsDW]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [AnalyticsDW]    Script Date: 6/19/2020 2:56:17 PM ******/
CREATE DATABASE [AnalyticsDW]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'AnalyticsDW', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL13.MSSQLSERVER\MSSQL\DATA\AnalyticsDW.mdf' , SIZE = 1253376KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'AnalyticsDW_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL13.MSSQLSERVER\MSSQL\DATA\AnalyticsDW_log.ldf' , SIZE = 15409152KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
GO
ALTER DATABASE [AnalyticsDW] SET COMPATIBILITY_LEVEL = 130
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [AnalyticsDW].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [AnalyticsDW] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [AnalyticsDW] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [AnalyticsDW] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [AnalyticsDW] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [AnalyticsDW] SET ARITHABORT OFF 
GO
ALTER DATABASE [AnalyticsDW] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [AnalyticsDW] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [AnalyticsDW] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [AnalyticsDW] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [AnalyticsDW] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [AnalyticsDW] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [AnalyticsDW] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [AnalyticsDW] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [AnalyticsDW] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [AnalyticsDW] SET  DISABLE_BROKER 
GO
ALTER DATABASE [AnalyticsDW] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [AnalyticsDW] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [AnalyticsDW] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [AnalyticsDW] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [AnalyticsDW] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [AnalyticsDW] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [AnalyticsDW] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [AnalyticsDW] SET RECOVERY FULL 
GO
ALTER DATABASE [AnalyticsDW] SET  MULTI_USER 
GO
ALTER DATABASE [AnalyticsDW] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [AnalyticsDW] SET DB_CHAINING OFF 
GO
ALTER DATABASE [AnalyticsDW] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [AnalyticsDW] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [AnalyticsDW] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [AnalyticsDW] SET QUERY_STORE = OFF
GO
USE [AnalyticsDW]
GO
ALTER DATABASE SCOPED CONFIGURATION SET LEGACY_CARDINALITY_ESTIMATION = OFF;
GO
ALTER DATABASE SCOPED CONFIGURATION SET MAXDOP = 0;
GO
ALTER DATABASE SCOPED CONFIGURATION SET PARAMETER_SNIFFING = ON;
GO
ALTER DATABASE SCOPED CONFIGURATION SET QUERY_OPTIMIZER_HOTFIXES = OFF;
GO

-- %% [markdown]
-- # [CCN\etoledo]

-- %%
USE [AnalyticsDW]
GO

-- %%
/****** Object:  User [CCN\etoledo]    Script Date: 6/19/2020 2:56:18 PM ******/
CREATE USER [CCN\etoledo] FOR LOGIN [CCN\etoledo] WITH DEFAULT_SCHEMA=[dbo]
GO

-- %% [markdown]
-- # [CCN\ermartinez]

-- %%
/****** Object:  User [CCN\ermartinez]    Script Date: 6/19/2020 2:56:18 PM ******/
CREATE USER [CCN\ermartinez] FOR LOGIN [CCN\ermartinez] WITH DEFAULT_SCHEMA=[dbo]
GO

-- %% [markdown]
-- # [CCN\etoledo]

-- %%
ALTER ROLE [db_owner] ADD MEMBER [CCN\etoledo]
GO

-- %% [markdown]
-- # [CCN\ermartinez]

-- %%
ALTER ROLE [db_owner] ADD MEMBER [CCN\ermartinez]
GO

-- %% [markdown]
-- # [dbo].[DimAccountMovement]

-- %%
/****** Object:  Table [dbo].[DimAccountMovement]    Script Date: 6/19/2020 2:56:18 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DimAccountMovement](
	[AccountMovementKey] [int] NOT NULL,
	[AccountMovementAlternateKey] [int] NOT NULL,
	[AccountMovementName] [nvarchar](100) NOT NULL,
 CONSTRAINT [PK_DimAccountMovement_AccountMovementKey] PRIMARY KEY CLUSTERED 
(
	[AccountMovementKey] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DimClient]

-- %%
/****** Object:  Table [dbo].[DimClient]    Script Date: 6/19/2020 2:56:18 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DimClient](
	[ClientKey] [int] NOT NULL,
	[ClientAlternateKey] [int] NOT NULL,
	[CompanyAlternateKey] [int] NOT NULL,
	[ClientName] [nvarchar](300) NOT NULL,
	[ClientAddress] [nvarchar](500) NOT NULL,
	[ClientStatusKey] [int] NOT NULL,
	[ClientGeoPosX] [decimal](18, 6) NOT NULL,
	[ClientGeoPosY] [decimal](18, 6) NOT NULL,
	[ClientGeoPosZ] [decimal](18, 6) NOT NULL,
	[GeographyKey] [int] NOT NULL,
 CONSTRAINT [PK_Client_ClientKey] PRIMARY KEY CLUSTERED 
(
	[ClientKey] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DimClientDebt]

-- %%
/****** Object:  Table [dbo].[DimClientDebt]    Script Date: 6/19/2020 2:56:18 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DimClientDebt](
	[ClientDebtKey] [int] NOT NULL,
	[ClientKey] [int] NOT NULL,
	[CompanyAlternateKey] [int] NOT NULL,
	[ClientAlternateKey] [int] NOT NULL,
	[CheckDate] [int] NOT NULL,
	[DebtAmount] [float] NOT NULL,
 CONSTRAINT [PK_ClientDefault_ClientDefaultKey] PRIMARY KEY CLUSTERED 
(
	[ClientDebtKey] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DimClientGroup]

-- %%
/****** Object:  Table [dbo].[DimClientGroup]    Script Date: 6/19/2020 2:56:18 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DimClientGroup](
	[ClientGroupKey] [int] NOT NULL,
	[ClientGroupAlternateKey] [int] NOT NULL,
	[CompanyAlternateKey] [int] NOT NULL,
	[PromotionPolicyTypeAlternateKey] [nvarchar](100) NOT NULL,
	[ClientGroupName] [nvarchar](100) NOT NULL,
 CONSTRAINT [PK_ClientGroup_ClientKey] PRIMARY KEY CLUSTERED 
(
	[ClientGroupKey] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DimClientGroupDet]

-- %%
/****** Object:  Table [dbo].[DimClientGroupDet]    Script Date: 6/19/2020 2:56:18 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DimClientGroupDet](
	[ClientGroupDetKey] [int] NOT NULL,
	[ClientGroupKey] [int] NOT NULL,
	[CompanyAlternateKey] [int] NOT NULL,
	[PromotionPolicyTypeAlternateKey] [nvarchar](100) NOT NULL,
	[ClientGroupAlternateKey] [int] NOT NULL,
	[ClientAlternateKey] [int] NOT NULL,
	[ClientKey] [int] NULL,
 CONSTRAINT [PK_ClientGroupDet_ClientGroupDetKey] PRIMARY KEY CLUSTERED 
(
	[ClientGroupDetKey] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DimCompany]

-- %%
/****** Object:  Table [dbo].[DimCompany]    Script Date: 6/19/2020 2:56:18 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DimCompany](
	[CompanyKey] [int] NOT NULL,
	[CompanyAlternateKey] [int] NOT NULL,
	[CompanyName] [nvarchar](100) NOT NULL,
 CONSTRAINT [PK_DimCompany_CompanyKey] PRIMARY KEY CLUSTERED 
(
	[CompanyKey] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DimCurrency]

-- %%
/****** Object:  Table [dbo].[DimCurrency]    Script Date: 6/19/2020 2:56:18 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DimCurrency](
	[CurrencyKey] [int] IDENTITY(1,1) NOT NULL,
	[CurrencyAlternateKey] [nchar](3) NOT NULL,
	[CurrencyName] [nvarchar](300) NOT NULL,
 CONSTRAINT [PK_DimCurrency_CurrencyKey] PRIMARY KEY CLUSTERED 
(
	[CurrencyKey] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DimDate]

-- %%
/****** Object:  Table [dbo].[DimDate]    Script Date: 6/19/2020 2:56:18 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DimDate](
	[DateKey] [int] NOT NULL,
	[FullDateAlternateKey] [date] NOT NULL,
	[DayNumberOfWeek] [tinyint] NOT NULL,
	[EnglishDayNameOfWeek] [nvarchar](10) NOT NULL,
	[SpanishDayNameOfWeek] [nvarchar](10) NOT NULL,
	[FrenchDayNameOfWeek] [nvarchar](10) NOT NULL,
	[DayNumberOfMonth] [tinyint] NOT NULL,
	[DayNumberOfYear] [smallint] NOT NULL,
	[WeekNumberOfYear] [tinyint] NOT NULL,
	[EnglishMonthName] [nvarchar](10) NOT NULL,
	[SpanishMonthName] [nvarchar](10) NOT NULL,
	[FrenchMonthName] [nvarchar](10) NOT NULL,
	[MonthNumberOfYear] [tinyint] NOT NULL,
	[CalendarQuarter] [tinyint] NOT NULL,
	[CalendarYear] [smallint] NOT NULL,
	[CalendarSemester] [tinyint] NOT NULL,
	[FiscalQuarter] [tinyint] NOT NULL,
	[FiscalYear] [smallint] NOT NULL,
	[FiscalSemester] [tinyint] NOT NULL,
 CONSTRAINT [PK_DimDate_DateKey] PRIMARY KEY CLUSTERED 
(
	[DateKey] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY],
 CONSTRAINT [AK_DimDate_FullDateAlternateKey] UNIQUE NONCLUSTERED 
(
	[FullDateAlternateKey] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DimGeography]

-- %%
/****** Object:  Table [dbo].[DimGeography]    Script Date: 6/19/2020 2:56:18 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DimGeography](
	[GeographyKey] [int] NOT NULL,
	[NeighborhoodAlternateKey] [nvarchar](15) NOT NULL,
	[NeighborhoodAlternateName] [nvarchar](100) NOT NULL,
	[MunicipalityAlternateKey] [int] NOT NULL,
	[MunicipalityAlternateName] [int] NOT NULL,
	[DepartmentAlternateKey] [nvarchar](15) NOT NULL,
	[DepartmentAlternateName] [nvarchar](100) NOT NULL,
	[RegionAlternateKey] [int] NOT NULL,
	[RegionAlternateName] [nvarchar](100) NOT NULL,
	[CountryAlternateKey] [nvarchar](15) NOT NULL,
	[CountryAlternateName] [nvarchar](100) NOT NULL,
 CONSTRAINT [PK_DimGeography_GeographyKey] PRIMARY KEY CLUSTERED 
(
	[GeographyKey] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DimProduct]

-- %%
/****** Object:  Table [dbo].[DimProduct]    Script Date: 6/19/2020 2:56:18 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DimProduct](
	[ProductKey] [int] NOT NULL,
	[ProductAlternateKey] [int] NOT NULL,
	[CompanyAlternateKey] [int] NOT NULL,
	[ProductName] [nvarchar](100) NOT NULL,
	[ProductStatusKey] [int] NOT NULL,
 CONSTRAINT [PK_Product_ProductKey] PRIMARY KEY CLUSTERED 
(
	[ProductKey] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DimProductConsignment]

-- %%
/****** Object:  Table [dbo].[DimProductConsignment]    Script Date: 6/19/2020 2:56:18 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DimProductConsignment](
	[ProductConsignmentKey] [int] NOT NULL,
	[ProductKey] [int] NOT NULL,
	[ClientKey] [int] NOT NULL,
	[ConsignmentDateKey] [int] NOT NULL,
	[DueDateKey] [int] NOT NULL,
	[AccountMovementKey] [int] NOT NULL,
	[CurrencyKey] [int] NOT NULL,
	[ConsignmentQuantity] [smallint] NOT NULL,
	[ConsignmentAmount] [money] NOT NULL,
	[ConsignmentMotive] [nvarchar](10) NOT NULL,
	[CompanyAlternateKey] [int] NOT NULL,
	[ProductAlternateKey] [int] NOT NULL,
	[ClientAlternateKey] [int] NOT NULL,
	[ConsignmentAlternateDateKey] [date] NOT NULL,
	[DueDateAlternateKey] [date] NOT NULL,
	[AccountMovementAlternateKey] [int] NOT NULL,
 CONSTRAINT [PK_DimProductConsignment_ProductConsignmentKey] PRIMARY KEY CLUSTERED 
(
	[ProductConsignmentKey] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DimProductGroup]

-- %%
/****** Object:  Table [dbo].[DimProductGroup]    Script Date: 6/19/2020 2:56:18 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DimProductGroup](
	[ProductGroupKey] [int] NOT NULL,
	[ProductGroupAlternateKey] [int] NOT NULL,
	[CompanyAlternateKey] [int] NOT NULL,
	[PromotionPolicyTypeAlternateKey] [nvarchar](100) NOT NULL,
	[ProductGroupName] [nvarchar](100) NOT NULL,
 CONSTRAINT [PK_ProductGroup_ProductGroupKey] PRIMARY KEY CLUSTERED 
(
	[ProductGroupKey] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DimProductGroupDet]

-- %%
/****** Object:  Table [dbo].[DimProductGroupDet]    Script Date: 6/19/2020 2:56:18 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DimProductGroupDet](
	[ProductGroupKeyDet] [int] NOT NULL,
	[ProductGroupKey] [int] NOT NULL,
	[CompanyAlternateKey] [int] NOT NULL,
	[PromotionPolicyTypeAlternateKey] [nvarchar](100) NOT NULL,
	[ProductGroupAlternateKey] [int] NOT NULL,
	[ProductAlternateKey] [int] NOT NULL,
	[ProductKey] [int] NULL,
 CONSTRAINT [PK_ProductGroupDet_ProductGroupDetKey] PRIMARY KEY CLUSTERED 
(
	[ProductGroupKeyDet] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DimProductStatus]

-- %%
/****** Object:  Table [dbo].[DimProductStatus]    Script Date: 6/19/2020 2:56:18 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DimProductStatus](
	[ProductStatusKey] [int] NOT NULL,
	[ProductStatusAlternateKey] [int] NOT NULL,
	[CompanyAlternateKey] [int] NOT NULL,
	[ProductStatusName] [nvarchar](100) NOT NULL,
 CONSTRAINT [PK_DimProductStatus_ProductStatusKey] PRIMARY KEY CLUSTERED 
(
	[ProductStatusKey] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DimPromotion]

-- %%
/****** Object:  Table [dbo].[DimPromotion]    Script Date: 6/19/2020 2:56:18 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DimPromotion](
	[PromotionKey] [int] NOT NULL,
	[CompanyAlternateKey] [int] NOT NULL,
	[PromotionAlternateKey] [int] NOT NULL,
	[ScaleAlternateKey] [int] NOT NULL,
	[ScaleVersionAlternateKey] [int] NOT NULL,
	[ClientGroupAlternateKey] [int] NOT NULL,
	[ProductGroupAlternateKey] [int] NOT NULL,
	[PromotionPolicyTypeAlternateKey] [nvarchar](100) NOT NULL,
	[PromotionName] [nvarchar](255) NOT NULL,
	[ScaleName] [nvarchar](255) NOT NULL,
	[DiscountPct] [float] NOT NULL,
	[StartDate] [datetime] NOT NULL,
	[EndDate] [datetime] NOT NULL,
	[PromoStatus] [nvarchar](255) NOT NULL,
	[Exclusionary] [tinyint] NOT NULL,
	[ClientGroupKey] [int] NOT NULL,
	[ProductGroupKey] [int] NOT NULL,
	[PromotionPolicyTypeKey] [int] NOT NULL,
 CONSTRAINT [PK_DimPromotion_PromotionKey] PRIMARY KEY CLUSTERED 
(
	[PromotionKey] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DimPromotionPolicyType]

-- %%
/****** Object:  Table [dbo].[DimPromotionPolicyType]    Script Date: 6/19/2020 2:56:18 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DimPromotionPolicyType](
	[PromotionPolicyTypeKey] [int] NOT NULL,
	[CompanyAlternateKey] [int] NOT NULL,
	[PromotionPolicyTypeAlternateKey] [nvarchar](100) NOT NULL,
	[PromotionPolicyTypeName] [nvarchar](100) NOT NULL,
 CONSTRAINT [PK_PromotionPolicyType_PromotionPolicyTypeKey] PRIMARY KEY CLUSTERED 
(
	[PromotionPolicyTypeKey] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ExecutionLevel]

-- %%
/****** Object:  Table [dbo].[ExecutionLevel]    Script Date: 6/19/2020 2:56:18 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ExecutionLevel](
	[ExecutionLevelKey] [int] IDENTITY(1,1) NOT NULL,
	[ExecutionLevelName] [nvarchar](100) NOT NULL,
	[Status] [smallint] NOT NULL,
 CONSTRAINT [PK_ExecutionLevel_ExecutionLevelKey] PRIMARY KEY CLUSTERED 
(
	[ExecutionLevelKey] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[FactAppliedPromotion]

-- %%
/****** Object:  Table [dbo].[FactAppliedPromotion]    Script Date: 6/19/2020 2:56:18 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[FactAppliedPromotion](
	[AppliedPromotionKey] [int] NOT NULL,
	[ClientKey] [int] NOT NULL,
	[ProductKey] [int] NOT NULL,
	[PromotionKey] [int] NOT NULL,
	[OrderNumber] [int] NOT NULL,
	[BillInternalNumber] [int] NOT NULL,
	[BillNumber] [int] NOT NULL,
	[BillSerie] [nvarchar](50) NOT NULL,
	[DiscountPercentage] [float] NOT NULL,
	[OrderTotalQuantity] [float] NOT NULL,
	[OrderDiscountPerc] [float] NOT NULL,
	[OrderTotalDiscount] [float] NOT NULL,
	[OrderTotalAmount] [float] NOT NULL,
	[OrderGrossAmount] [float] NOT NULL,
	[ClientDebt] [float] NOT NULL,
	[SaleDate] [int] NOT NULL,
	[CompanyAlternateKey] [int] NOT NULL,
	[ClientAlternateKey] [int] NOT NULL,
	[ProductAlternateKey] [int] NOT NULL,
	[PromotionAlternateKey] [int] NOT NULL,
	[ScaleAlternateKey] [int] NOT NULL,
	[ScaleVersionAlternateKey] [int] NOT NULL,
	[ClientGroupAlternateKey] [int] NOT NULL,
	[ProductGroupAlternateKey] [int] NOT NULL,
	[PromotionPolicyTypeAlternateKey] [nvarchar](100) NOT NULL,
 CONSTRAINT [PK_AppliedPromotion_AppliedPromotionKey] PRIMARY KEY CLUSTERED 
(
	[AppliedPromotionKey] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[FactAssignedPromotion]

-- %%
/****** Object:  Table [dbo].[FactAssignedPromotion]    Script Date: 6/19/2020 2:56:18 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[FactAssignedPromotion](
	[AssignedPromotionKey] [int] NOT NULL,
	[ClientKey] [int] NOT NULL,
	[ProductKey] [int] NOT NULL,
	[PromotionKey] [int] NOT NULL,
	[CompanyAlternateKey] [int] NOT NULL,
	[ClientAlternateKey] [int] NOT NULL,
	[ProductAlternateKey] [int] NOT NULL,
	[PromotionAlternateKey] [int] NOT NULL,
	[ScaleAlternateKey] [int] NOT NULL,
	[ScaleVersionAlternateKey] [int] NOT NULL,
	[ClientGroupAlternateKey] [int] NOT NULL,
	[ProductGroupAlternateKey] [int] NOT NULL,
	[PromotionPolicyTypeAlternateKey] [nvarchar](100) NOT NULL,
	[DiscountPercentage] [float] NOT NULL,
	[DiscountQuantity] [float] NOT NULL,
	[ClientDebt] [float] NOT NULL,
	[ActivationDate] [int] NOT NULL,
	[EndDate] [int] NOT NULL,
 CONSTRAINT [PK_AssignedPromotion_AssignedPromotionKey] PRIMARY KEY CLUSTERED 
(
	[AssignedPromotionKey] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[FactProductSales]

-- %%
/****** Object:  Table [dbo].[FactProductSales]    Script Date: 6/19/2020 2:56:18 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[FactProductSales](
	[ProductSalesKey] [int] NOT NULL,
	[ProductKey] [int] NOT NULL,
	[ClientKey] [int] NOT NULL,
	[SalesDateKey] [int] NOT NULL,
	[CompanyKey] [int] NOT NULL,
	[AccountMovementKey] [int] NOT NULL,
	[CurrencyKey] [int] NOT NULL,
	[SalesInternalOrderNumber] [int] NOT NULL,
	[SalesOrderNumber] [int] NOT NULL,
	[SalesOrderLineNumber] [tinyint] NOT NULL,
	[OrderQuantity] [smallint] NOT NULL,
	[DiscountAmount] [float] NOT NULL,
	[SalesAmount] [money] NOT NULL,
	[CompanyAlternateKey] [int] NOT NULL,
	[ClientAlternateKey] [int] NOT NULL,
	[ProductAlternateKey] [int] NOT NULL,
	[AccountMovementAlternateKey] [int] NOT NULL,
	[TaxIVA] [money] NOT NULL,
	[TaxISC] [money] NOT NULL,
	[TaxIMI] [money] NOT NULL,
	[TaxICA] [money] NOT NULL,
	[PaymentTypeMovement] [nvarchar](100) NOT NULL,
	[MarketId] [nvarchar](100) NOT NULL,
	[MarketDesc] [nvarchar](100) NOT NULL,
	[FamilyId] [nvarchar](100) NOT NULL,
	[FamilyDesc] [nvarchar](100) NOT NULL,
	[BrandId] [nvarchar](100) NOT NULL,
	[BrandDesc] [nvarchar](100) NOT NULL,
	[PresentationId] [nvarchar](100) NOT NULL,
	[PresentationDesc] [nvarchar](100) NOT NULL,
	[ExchangeRate] [money] NOT NULL,
 CONSTRAINT [PK_FactProductSales] PRIMARY KEY CLUSTERED 
(
	[ProductSalesKey] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[LookupNoMatch]

-- %%
/****** Object:  Table [dbo].[LookupNoMatch]    Script Date: 6/19/2020 2:56:18 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[LookupNoMatch](
	[LookupNoMatchKey] [int] IDENTITY(1,1) NOT NULL,
	[TableName] [nvarchar](100) NOT NULL,
	[NoMatchRow] [nvarchar](4000) NOT NULL,
	[TimeStampEvent] [datetime2](7) NOT NULL,
 CONSTRAINT [PK_LookupNoMatch_LookupNoMatchKey] PRIMARY KEY CLUSTERED 
(
	[LookupNoMatchKey] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK_DimClient_DimGeography]

-- %%
ALTER TABLE [dbo].[DimClient]  WITH CHECK ADD  CONSTRAINT [FK_DimClient_DimGeography] FOREIGN KEY([GeographyKey])
REFERENCES [dbo].[DimGeography] ([GeographyKey])
GO
ALTER TABLE [dbo].[DimClient] CHECK CONSTRAINT [FK_DimClient_DimGeography]
GO

-- %% [markdown]
-- # [FK_DimClientDefault_DimClient]

-- %%
ALTER TABLE [dbo].[DimClientDebt]  WITH CHECK ADD  CONSTRAINT [FK_DimClientDefault_DimClient] FOREIGN KEY([ClientKey])
REFERENCES [dbo].[DimClient] ([ClientKey])
GO
ALTER TABLE [dbo].[DimClientDebt] CHECK CONSTRAINT [FK_DimClientDefault_DimClient]
GO

-- %% [markdown]
-- # [FK_DimClientGroupDet_DimClient]

-- %%
ALTER TABLE [dbo].[DimClientGroupDet]  WITH CHECK ADD  CONSTRAINT [FK_DimClientGroupDet_DimClient] FOREIGN KEY([ClientKey])
REFERENCES [dbo].[DimClient] ([ClientKey])
GO
ALTER TABLE [dbo].[DimClientGroupDet] CHECK CONSTRAINT [FK_DimClientGroupDet_DimClient]
GO

-- %% [markdown]
-- # [FK_DimClientGroupDet_DimClientGroup]

-- %%
ALTER TABLE [dbo].[DimClientGroupDet]  WITH NOCHECK ADD  CONSTRAINT [FK_DimClientGroupDet_DimClientGroup] FOREIGN KEY([ClientGroupAlternateKey])
REFERENCES [dbo].[DimClientGroup] ([ClientGroupKey])
GO
ALTER TABLE [dbo].[DimClientGroupDet] CHECK CONSTRAINT [FK_DimClientGroupDet_DimClientGroup]
GO

-- %% [markdown]
-- # [FK_DimProduct_DimProductStatus]

-- %%
ALTER TABLE [dbo].[DimProduct]  WITH NOCHECK ADD  CONSTRAINT [FK_DimProduct_DimProductStatus] FOREIGN KEY([ProductStatusKey])
REFERENCES [dbo].[DimProductStatus] ([ProductStatusKey])
GO
ALTER TABLE [dbo].[DimProduct] CHECK CONSTRAINT [FK_DimProduct_DimProductStatus]
GO

-- %% [markdown]
-- # [FK_DimProductConsignment_DimAccountMovement]

-- %%
ALTER TABLE [dbo].[DimProductConsignment]  WITH CHECK ADD  CONSTRAINT [FK_DimProductConsignment_DimAccountMovement] FOREIGN KEY([AccountMovementKey])
REFERENCES [dbo].[DimAccountMovement] ([AccountMovementKey])
GO
ALTER TABLE [dbo].[DimProductConsignment] CHECK CONSTRAINT [FK_DimProductConsignment_DimAccountMovement]
GO

-- %% [markdown]
-- # [FK_DimProductConsignment_DimClient]

-- %%
ALTER TABLE [dbo].[DimProductConsignment]  WITH CHECK ADD  CONSTRAINT [FK_DimProductConsignment_DimClient] FOREIGN KEY([ClientKey])
REFERENCES [dbo].[DimClient] ([ClientKey])
GO
ALTER TABLE [dbo].[DimProductConsignment] CHECK CONSTRAINT [FK_DimProductConsignment_DimClient]
GO

-- %% [markdown]
-- # [FK_DimProductConsignment_DimCurrency]

-- %%
ALTER TABLE [dbo].[DimProductConsignment]  WITH CHECK ADD  CONSTRAINT [FK_DimProductConsignment_DimCurrency] FOREIGN KEY([CurrencyKey])
REFERENCES [dbo].[DimCurrency] ([CurrencyKey])
GO
ALTER TABLE [dbo].[DimProductConsignment] CHECK CONSTRAINT [FK_DimProductConsignment_DimCurrency]
GO

-- %% [markdown]
-- # [FK_DimProductConsignment_DimProduct]

-- %%
ALTER TABLE [dbo].[DimProductConsignment]  WITH CHECK ADD  CONSTRAINT [FK_DimProductConsignment_DimProduct] FOREIGN KEY([ProductKey])
REFERENCES [dbo].[DimProduct] ([ProductKey])
GO
ALTER TABLE [dbo].[DimProductConsignment] CHECK CONSTRAINT [FK_DimProductConsignment_DimProduct]
GO

-- %% [markdown]
-- # [FK_DimProductGroupDet_DimProduct]

-- %%
ALTER TABLE [dbo].[DimProductGroupDet]  WITH CHECK ADD  CONSTRAINT [FK_DimProductGroupDet_DimProduct] FOREIGN KEY([ProductKey])
REFERENCES [dbo].[DimProduct] ([ProductKey])
GO
ALTER TABLE [dbo].[DimProductGroupDet] CHECK CONSTRAINT [FK_DimProductGroupDet_DimProduct]
GO

-- %% [markdown]
-- # [FK_DimProductGroupDet_DimProductGroup]

-- %%
ALTER TABLE [dbo].[DimProductGroupDet]  WITH NOCHECK ADD  CONSTRAINT [FK_DimProductGroupDet_DimProductGroup] FOREIGN KEY([ProductGroupKey])
REFERENCES [dbo].[DimProductGroup] ([ProductGroupKey])
GO
ALTER TABLE [dbo].[DimProductGroupDet] CHECK CONSTRAINT [FK_DimProductGroupDet_DimProductGroup]
GO

-- %% [markdown]
-- # [FK_FactAppliedPromotion_DimClient]

-- %%
ALTER TABLE [dbo].[FactAppliedPromotion]  WITH CHECK ADD  CONSTRAINT [FK_FactAppliedPromotion_DimClient] FOREIGN KEY([ClientKey])
REFERENCES [dbo].[DimClient] ([ClientKey])
GO
ALTER TABLE [dbo].[FactAppliedPromotion] CHECK CONSTRAINT [FK_FactAppliedPromotion_DimClient]
GO

-- %% [markdown]
-- # [FK_FactAppliedPromotion_DimProduct]

-- %%
ALTER TABLE [dbo].[FactAppliedPromotion]  WITH CHECK ADD  CONSTRAINT [FK_FactAppliedPromotion_DimProduct] FOREIGN KEY([ProductKey])
REFERENCES [dbo].[DimProduct] ([ProductKey])
GO
ALTER TABLE [dbo].[FactAppliedPromotion] CHECK CONSTRAINT [FK_FactAppliedPromotion_DimProduct]
GO

-- %% [markdown]
-- # [FK_FactAppliedPromotion_DimPromotion]

-- %%
ALTER TABLE [dbo].[FactAppliedPromotion]  WITH CHECK ADD  CONSTRAINT [FK_FactAppliedPromotion_DimPromotion] FOREIGN KEY([PromotionKey])
REFERENCES [dbo].[DimPromotion] ([PromotionKey])
GO
ALTER TABLE [dbo].[FactAppliedPromotion] CHECK CONSTRAINT [FK_FactAppliedPromotion_DimPromotion]
GO

-- %% [markdown]
-- # [FK_FactAssignedPromotion_DimClient]

-- %%
ALTER TABLE [dbo].[FactAssignedPromotion]  WITH CHECK ADD  CONSTRAINT [FK_FactAssignedPromotion_DimClient] FOREIGN KEY([ClientKey])
REFERENCES [dbo].[DimClient] ([ClientKey])
GO
ALTER TABLE [dbo].[FactAssignedPromotion] CHECK CONSTRAINT [FK_FactAssignedPromotion_DimClient]
GO

-- %% [markdown]
-- # [FK_FactAssignedPromotion_DimProduct]

-- %%
ALTER TABLE [dbo].[FactAssignedPromotion]  WITH CHECK ADD  CONSTRAINT [FK_FactAssignedPromotion_DimProduct] FOREIGN KEY([ProductKey])
REFERENCES [dbo].[DimProduct] ([ProductKey])
GO
ALTER TABLE [dbo].[FactAssignedPromotion] CHECK CONSTRAINT [FK_FactAssignedPromotion_DimProduct]
GO

-- %% [markdown]
-- # [FK_FactAssignedPromotion_DimPromotion]

-- %%
ALTER TABLE [dbo].[FactAssignedPromotion]  WITH CHECK ADD  CONSTRAINT [FK_FactAssignedPromotion_DimPromotion] FOREIGN KEY([PromotionKey])
REFERENCES [dbo].[DimPromotion] ([PromotionKey])
GO
ALTER TABLE [dbo].[FactAssignedPromotion] CHECK CONSTRAINT [FK_FactAssignedPromotion_DimPromotion]
GO

-- %% [markdown]
-- # [FK_FactProductSales_DimAccountMovement]

-- %%
ALTER TABLE [dbo].[FactProductSales]  WITH CHECK ADD  CONSTRAINT [FK_FactProductSales_DimAccountMovement] FOREIGN KEY([AccountMovementKey])
REFERENCES [dbo].[DimAccountMovement] ([AccountMovementKey])
GO
ALTER TABLE [dbo].[FactProductSales] CHECK CONSTRAINT [FK_FactProductSales_DimAccountMovement]
GO

-- %% [markdown]
-- # [FK_FactProductSales_DimClient]

-- %%
ALTER TABLE [dbo].[FactProductSales]  WITH CHECK ADD  CONSTRAINT [FK_FactProductSales_DimClient] FOREIGN KEY([ClientKey])
REFERENCES [dbo].[DimClient] ([ClientKey])
GO
ALTER TABLE [dbo].[FactProductSales] CHECK CONSTRAINT [FK_FactProductSales_DimClient]
GO

-- %% [markdown]
-- # [FK_FactProductSales_DimCompany]

-- %%
ALTER TABLE [dbo].[FactProductSales]  WITH CHECK ADD  CONSTRAINT [FK_FactProductSales_DimCompany] FOREIGN KEY([CompanyKey])
REFERENCES [dbo].[DimCompany] ([CompanyKey])
GO
ALTER TABLE [dbo].[FactProductSales] CHECK CONSTRAINT [FK_FactProductSales_DimCompany]
GO

-- %% [markdown]
-- # [FK_FactProductSales_DimCurrency]

-- %%
ALTER TABLE [dbo].[FactProductSales]  WITH CHECK ADD  CONSTRAINT [FK_FactProductSales_DimCurrency] FOREIGN KEY([CurrencyKey])
REFERENCES [dbo].[DimCurrency] ([CurrencyKey])
GO
ALTER TABLE [dbo].[FactProductSales] CHECK CONSTRAINT [FK_FactProductSales_DimCurrency]
GO

-- %% [markdown]
-- # [FK_FactProductSales_DimProduct]

-- %%
ALTER TABLE [dbo].[FactProductSales]  WITH CHECK ADD  CONSTRAINT [FK_FactProductSales_DimProduct] FOREIGN KEY([ProductKey])
REFERENCES [dbo].[DimProduct] ([ProductKey])
GO
ALTER TABLE [dbo].[FactProductSales] CHECK CONSTRAINT [FK_FactProductSales_DimProduct]
GO

-- %% [markdown]
-- # [dbo].[truncate_tables_D_L1]

-- %%
/****** Object:  StoredProcedure [dbo].[truncate_tables_D_L1]    Script Date: 6/19/2020 2:56:18 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO













CREATE PROCEDURE [dbo].[truncate_tables_D_L1] AS
BEGIN
      ALTER TABLE [dbo].[FactProductSales] DROP CONSTRAINT [FK_FactProductSales_DimCompany];

      truncate table [AnalyticsDW].[dbo].[DimCompany];
	  
	  ALTER TABLE [dbo].[FactProductSales]  WITH CHECK ADD  CONSTRAINT [FK_FactProductSales_DimCompany] FOREIGN KEY([CompanyKey]) REFERENCES [dbo].[DimCompany] ([CompanyKey]);

      ALTER TABLE [dbo].[FactProductSales] CHECK CONSTRAINT [FK_FactProductSales_DimCompany];

	  ALTER TABLE [dbo].[DimProductConsignment] DROP CONSTRAINT [FK_DimProductConsignment_DimProduct];

	  ALTER TABLE [dbo].[FactAppliedPromotion] DROP CONSTRAINT [FK_FactAppliedPromotion_DimProduct];

	  ALTER TABLE [dbo].[FactAssignedPromotion] DROP CONSTRAINT [FK_FactAssignedPromotion_DimProduct];

	  ALTER TABLE [dbo].[FactProductSales] DROP CONSTRAINT [FK_FactProductSales_DimProduct];

	  truncate table [AnalyticsDW].[dbo].[DimProduct];

	  ALTER TABLE [dbo].[DimProductConsignment]  WITH CHECK ADD  CONSTRAINT [FK_DimProductConsignment_DimProduct] FOREIGN KEY([ProductKey]) REFERENCES [dbo].[DimProduct] ([ProductKey]);

	  ALTER TABLE [dbo].[DimProductConsignment] CHECK CONSTRAINT [FK_DimProductConsignment_DimProduct];

	  ALTER TABLE [dbo].[FactAppliedPromotion]  WITH CHECK ADD  CONSTRAINT [FK_FactAppliedPromotion_DimProduct] FOREIGN KEY([ProductKey]) REFERENCES [dbo].[DimProduct] ([ProductKey]);

	  ALTER TABLE [dbo].[FactAppliedPromotion] CHECK CONSTRAINT [FK_FactAppliedPromotion_DimProduct];

	  ALTER TABLE [dbo].[FactAssignedPromotion]  WITH CHECK ADD  CONSTRAINT [FK_FactAssignedPromotion_DimProduct] FOREIGN KEY([ProductKey]) REFERENCES [dbo].[DimProduct] ([ProductKey]);

	  ALTER TABLE [dbo].[FactAssignedPromotion] CHECK CONSTRAINT [FK_FactAssignedPromotion_DimProduct];

	  ALTER TABLE [dbo].[FactProductSales]  WITH CHECK ADD  CONSTRAINT [FK_FactProductSales_DimProduct] FOREIGN KEY([ProductKey]) REFERENCES [dbo].[DimProduct] ([ProductKey]);

	  ALTER TABLE [dbo].[FactProductSales] CHECK CONSTRAINT [FK_FactProductSales_DimProduct];
      
	  ALTER TABLE [dbo].[DimProduct] DROP CONSTRAINT [FK_DimProduct_DimProductStatus];

	  truncate table [AnalyticsDW].[dbo].[DimProductStatus];

	  ALTER TABLE [dbo].[DimProduct]  WITH CHECK ADD  CONSTRAINT [FK_DimProduct_DimProductStatus] FOREIGN KEY([ProductStatusKey]) REFERENCES [dbo].[DimProductStatus] ([ProductStatusKey]);

	  ALTER TABLE [dbo].[DimProduct] CHECK CONSTRAINT [FK_DimProduct_DimProductStatus];

	  ALTER TABLE [dbo].[DimPromotion] DROP CONSTRAINT [FK_DimPromotion_DimPromotionPolicyType];

      truncate table [AnalyticsDW].[dbo].[DimPromotionPolicyType];

      ALTER TABLE [dbo].[DimPromotion]  WITH CHECK ADD  CONSTRAINT [FK_DimPromotion_DimPromotionPolicyType] FOREIGN KEY([PromotionPolicyTypeKey]) REFERENCES [dbo].[DimPromotionPolicyType] ([PromotionPolicyTypeKey]);

      ALTER TABLE [dbo].[DimPromotion] CHECK CONSTRAINT [FK_DimPromotion_DimPromotionPolicyType];

	  --ALTER TABLE [dbo].[DimPromotion] DROP CONSTRAINT [FK_DimPromotion_DimProductGroupDet];

	  truncate table [AnalyticsDW].[dbo].[DimProductGroupDet];

	  --ALTER TABLE [dbo].[DimPromotion]  WITH CHECK ADD  CONSTRAINT [FK_DimPromotion_DimProductGroupDet] FOREIGN KEY([ProductGroupDetKey]) REFERENCES [dbo].[DimProductGroupDet] ([ProductGroupKeyDet]);

	  --ALTER TABLE [dbo].[DimPromotion] CHECK CONSTRAINT [FK_DimPromotion_DimProductGroupDet];

	  ALTER TABLE [dbo].[DimProductGroupDet] DROP CONSTRAINT [FK_DimProductGroupDet_DimProductGroup];

	  ALTER TABLE [dbo].[DimPromotion] DROP CONSTRAINT [FK_DimPromotion_DimProductGroup];

	  truncate table [AnalyticsDW].[dbo].[DimProductGroup];

	  ALTER TABLE [dbo].[DimProductGroupDet]  WITH CHECK ADD  CONSTRAINT [FK_DimProductGroupDet_DimProductGroup] FOREIGN KEY([ProductGroupKey]) REFERENCES [dbo].[DimProductGroup] ([ProductGroupKey]);

	  ALTER TABLE [dbo].[DimProductGroupDet] CHECK CONSTRAINT [FK_DimProductGroupDet_DimProductGroup];

	  ALTER TABLE [dbo].[DimPromotion]  WITH CHECK ADD  CONSTRAINT [FK_DimPromotion_DimProductGroup] FOREIGN KEY([ProductGroupKey]) REFERENCES [dbo].[DimProductGroup] ([ProductGroupKey]);

	  ALTER TABLE [dbo].[DimPromotion] CHECK CONSTRAINT [FK_DimPromotion_DimProductGroup];

	  --ALTER TABLE [dbo].[DimPromotion] DROP CONSTRAINT [FK_DimPromotion_DimClientGroupDet];

	  truncate table [AnalyticsDW].[dbo].[DimClientGroupDet];

	  --ALTER TABLE [dbo].[DimPromotion]  WITH CHECK ADD  CONSTRAINT [FK_DimPromotion_DimClientGroupDet] FOREIGN KEY([ClientGroupDetKey]) REFERENCES [dbo].[DimClientGroupDet] ([ClientGroupDetKey]);

	  --ALTER TABLE [dbo].[DimPromotion] CHECK CONSTRAINT [FK_DimPromotion_DimClientGroupDet];

	  ALTER TABLE [dbo].[DimClientGroupDet] DROP CONSTRAINT [FK_DimClientGroupDet_DimClientGroup];

	  ALTER TABLE [dbo].[DimPromotion] DROP CONSTRAINT [FK_DimPromotion_DimClientGroup];

	  truncate table [AnalyticsDW].[dbo].[DimClientGroup];

	  ALTER TABLE [dbo].[DimClientGroupDet]  WITH CHECK ADD  CONSTRAINT [FK_DimClientGroupDet_DimClientGroup] FOREIGN KEY([ClientGroupAlternateKey]) REFERENCES [dbo].[DimClientGroup] ([ClientGroupKey]);

	  ALTER TABLE [dbo].[DimClientGroupDet] CHECK CONSTRAINT [FK_DimClientGroupDet_DimClientGroup];

	  ALTER TABLE [dbo].[DimPromotion]  WITH CHECK ADD  CONSTRAINT [FK_DimPromotion_DimClientGroup] FOREIGN KEY([ClientGroupKey]) REFERENCES [dbo].[DimClientGroup] ([ClientGroupKey]);

	  ALTER TABLE [dbo].[DimPromotion] CHECK CONSTRAINT [FK_DimPromotion_DimClientGroup];

	  truncate table [AnalyticsDW].[dbo].[LookupNoMatch];
END;
GO

-- %% [markdown]
-- # [dbo].[truncate_tables_D_L2]

-- %%
/****** Object:  StoredProcedure [dbo].[truncate_tables_D_L2]    Script Date: 6/19/2020 2:56:18 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE PROCEDURE [dbo].[truncate_tables_D_L2] AS
BEGIN
      ALTER TABLE [dbo].[FactAppliedPromotion] DROP CONSTRAINT [FK_FactAppliedPromotion_DimPromotion];

      ALTER TABLE [dbo].[FactAssignedPromotion] DROP CONSTRAINT [FK_FactAssignedPromotion_DimPromotion];

      ALTER TABLE [dbo].[FactProductSales] DROP CONSTRAINT [FK_FactProductSales_DimPromotion];

      truncate table [AnalyticsDW].[dbo].[DimPromotion];

      ALTER TABLE [dbo].[FactAppliedPromotion]  WITH CHECK ADD  CONSTRAINT [FK_FactAppliedPromotion_DimPromotion] FOREIGN KEY([PromotionKey]) REFERENCES [dbo].[DimPromotion] ([PromotionKey]);

      ALTER TABLE [dbo].[FactAppliedPromotion] CHECK CONSTRAINT [FK_FactAppliedPromotion_DimPromotion];

	  ALTER TABLE [dbo].[FactAssignedPromotion]  WITH CHECK ADD  CONSTRAINT [FK_FactAssignedPromotion_DimPromotion] FOREIGN KEY([PromotionKey]) REFERENCES [dbo].[DimPromotion] ([PromotionKey]);

	  ALTER TABLE [dbo].[FactAssignedPromotion] CHECK CONSTRAINT [FK_FactAssignedPromotion_DimPromotion];

	  ALTER TABLE [dbo].[FactProductSales]  WITH CHECK ADD  CONSTRAINT [FK_FactProductSales_DimPromotion] FOREIGN KEY([PromotionKey]) REFERENCES [dbo].[DimPromotion] ([PromotionKey]);

	  ALTER TABLE [dbo].[FactProductSales] CHECK CONSTRAINT [FK_FactProductSales_DimPromotion];

	  truncate table [AnalyticsDW].[dbo].[LookupNoMatch];
END;
GO

-- %% [markdown]
-- # [AnalyticsDW]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [AnalyticsDW] SET  READ_WRITE 
GO
